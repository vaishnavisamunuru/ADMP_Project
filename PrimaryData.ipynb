# %%
import pandas as pd

# %%
casualty5years_df = pd.read_csv('Data\PrimaryData\dft-road-casualty-statistics-casualty-last-5-years.csv',low_memory=False)
vehicle5years_df = pd.read_csv('Data\PrimaryData\dft-road-casualty-statistics-vehicle-last-5-years.csv',low_memory=False)
collision5years_df = pd.read_csv('Data\PrimaryData\dft-road-casualty-statistics-collision-last-5-years.csv',low_memory=False)

# %%
casualty2023_df = pd.read_csv('Data\PrimaryData\dft-road-casualty-statistics-casualty-provisional-mid-year-unvalidated-2023.csv',low_memory=False)
vehicle2023_df = pd.read_csv('Data\PrimaryData\dft-road-casualty-statistics-vehicle-provisional-mid-year-unvalidated-2023.csv',low_memory=False)
collision2023_df = pd.read_csv('Data\PrimaryData\dft-road-casualty-statistics-collision-provisional-mid-year-unvalidated-2023.csv',low_memory=False)

# %%
cols = {'accident_index':'collision_index','accident_year':'collision_year','accident_reference':'collision_reference',
        'accident_severity':'legacy_collision_severity','did_police_officer_attend_scene_of_accident':'did_police_officer_attend_scene_of_collision',
        'lsoa_of_accident_location':'lsoa_of_collision_location'}
casualty5years_df.rename(columns=cols,inplace=True)
vehicle5years_df.rename(columns=cols,inplace=True)
collision5years_df.rename(columns=cols,inplace=True)

# %%
print(casualty5years_df.shape)
print(vehicle5years_df.shape)
print(collision5years_df.shape)
# Out:
# (693028, 19)
# (990153, 28)
# (538461, 36)

# %%
print(casualty2023_df.shape)
print(vehicle2023_df.shape)
print(collision2023_df.shape)
# Out:
# (62674, 19)
# (89494, 28)
# (49316, 36)

# %%
casualty5years_df.columns == casualty2023_df.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
vehicle5years_df.columns == vehicle2023_df.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
collision5years_df.columns == collision2023_df.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True])

# %%
casualty_df = pd.concat([casualty5years_df,casualty2023_df],axis=0)
vehicle_df = pd.concat([vehicle5years_df,vehicle2023_df],axis=0)
collision_df = pd.concat([collision5years_df,collision2023_df],axis=0)

# %%
print(casualty_df.shape)
print(vehicle_df.shape)
print(collision_df.shape)
print(casualty2023_df.shape[0]+casualty5years_df.shape[0],casualty2023_df.shape[1])
print(vehicle2023_df.shape[0]+vehicle5years_df.shape[0],vehicle5years_df.shape[1])
print(collision2023_df.shape[0]+collision5years_df.shape[0],collision5years_df.shape[1])
# Out:
# (755702, 19)
# (1079647, 28)
# (587777, 36)
# 755702 19
# 1079647 28
# 587777 36

# %%
print(casualty5years_df.shape)
print(vehicle5years_df.shape)
print(collision5years_df.shape)
# Out:
# (693028, 19)
# (990153, 28)
# (538461, 36)

# %%
casualty_df[casualty_df.duplicated(subset=['collision_index'])]
# Out:
#       collision_index  collision_year collision_reference  vehicle_reference  \
# 1       2018010080971            2018           010080971                  2
# 6       2018010080982            2018           010080982                  2
# 8       2018010080983            2018           010080983                  1
# 9       2018010080983            2018           010080983                  1
# 10      2018010080983            2018           010080983                  2
# ...               ...             ...                 ...                ...
# 62636   2023991328668            2023           991328668                  4
# 62637   2023991328668            2023           991328668                  5
# 62638   2023991328668            2023           991328668                  6
# 62649   2023991339651            2023           991339651                  2
# 62654   2023991344073            2023           991344073                  2
#
# ...

# %%
collision_df[collision_df.duplicated(subset=['collision_index'])]
# Out:
# Empty DataFrame
# Columns: [collision_index, collision_year, collision_reference, location_easting_osgr, location_northing_osgr, longitude, latitude, police_force, legacy_collision_severity, number_of_vehicles, number_of_casualties, date, day_of_week, time, local_authority_district, local_authority_ons_district, local_authority_highway, first_road_class, first_road_number, road_type, speed_limit, junction_detail, junction_control, second_road_class, second_road_number, pedestrian_crossing_human_control, pedestrian_crossing_physical_facilities, light_conditions, weather_conditions, road_surface_conditions, special_conditions_at_site, carriageway_hazards, urban_or_rural_area, did_police_officer_attend_scene_of_collision, trunk_road_flag, lsoa_of_collision_location]
# Index: []
#
# [0 rows x 36 columns]

# %%
vehicle_df[vehicle_df.duplicated(subset=['collision_index'])]
# Out:
#       collision_index  collision_year collision_reference  vehicle_reference  \
# 1       2018010080971            2018           010080971                  2
# 4       2018010080974            2018           010080974                  2
# 6       2018010080981            2018           010080981                  2
# 8       2018010080982            2018           010080982                  2
# 10      2018010080983            2018           010080983                  2
# ...               ...             ...                 ...                ...
# 89481   2023991357840            2023           991357840                  2
# 89483   2023991357891            2023           991357891                  2
# 89487   2023991365442            2023           991365442                  2
# 89491   2023991369054            2023           991369054                  2
# 89493   2023991369155            2023           991369155                  2
#
# ...

# %%
vehicle_df[vehicle_df['collision_index']=='2018010080971']
# Out:
#   collision_index  collision_year collision_reference  vehicle_reference  \
# 0   2018010080971            2018           010080971                  1
# 1   2018010080971            2018           010080971                  2
#
#    vehicle_type  towing_and_articulation  vehicle_manoeuvre  \
# 0             9                        0                 18
# 1             8                        0                 18
#
#    vehicle_direction_from  vehicle_direction_to  \
# 0                       3                     7
# 1                       3                     7
#
#    vehicle_location_restricted_lane  ...  sex_of_driver  age_of_driver  \
# 0                                 0  ...              1             32
# 1                                 0  ...              1             48
#
#    age_band_of_driver  engine_capacity_cc  propulsion_code  age_of_vehicle  \
# 0                   6                1995                2               5
# ...

# %%
casualty_df[casualty_df['collision_index']=='2018010080971']
# Out:
#   collision_index  collision_year collision_reference  vehicle_reference  \
# 0   2018010080971            2018           010080971                  1
# 1   2018010080971            2018           010080971                  2
#
#    casualty_reference  casualty_class  sex_of_casualty  age_of_casualty  \
# 0                   1               2                2               50
# 1                   2               1                1               48
#
#    age_band_of_casualty  casualty_severity  pedestrian_location  \
# 0                     8                  3                    0
# 1                     8                  3                    0
#
#    pedestrian_movement  car_passenger  bus_or_coach_passenger  \
# 0                    0              2                       0
# 1                    0              0                       0
#
#    pedestrian_road_maintenance_worker  casualty_type  casualty_home_area_type  \
# ...

# %%
pd.set_option('display.max_columns',60)
collision_df[collision_df['collision_index']=='2018010080971']
# Out:
#   collision_index  collision_year collision_reference  location_easting_osgr  \
# 0   2018010080971            2018           010080971               529150.0
#
#    location_northing_osgr  longitude   latitude  police_force  \
# 0                182270.0  -0.139737  51.524587             1
#
#    legacy_collision_severity  number_of_vehicles  number_of_casualties  \
# 0                          3                   2                     2
#
#          date  day_of_week   time  local_authority_district  \
# 0  01/01/2018            2  01:30                         2
#
#   local_authority_ons_district local_authority_highway  first_road_class  \
# 0                    E09000007               E09000007                 3
#
#    first_road_number  road_type  speed_limit  junction_detail  \
# 0                501          3           30                0
#
#    junction_control  second_road_class  second_road_number  \
# 0                -1                  0                  -1
#
# ...

# %%
collision_df.columns
# Out:
# Index(['collision_index', 'collision_year', 'collision_reference',
#        'location_easting_osgr', 'location_northing_osgr', 'longitude',
#        'latitude', 'police_force', 'legacy_collision_severity',
#        'number_of_vehicles', 'number_of_casualties', 'date', 'day_of_week',
#        'time', 'local_authority_district', 'local_authority_ons_district',
#        'local_authority_highway', 'first_road_class', 'first_road_number',
#        'road_type', 'speed_limit', 'junction_detail', 'junction_control',
#        'second_road_class', 'second_road_number',
#        'pedestrian_crossing_human_control',
#        'pedestrian_crossing_physical_facilities', 'light_conditions',
#        'weather_conditions', 'road_surface_conditions',
#        'special_conditions_at_site', 'carriageway_hazards',
#        'urban_or_rural_area', 'did_police_officer_attend_scene_of_collision',
#        'trunk_road_flag', 'lsoa_of_collision_location'],
#       dtype='object')
